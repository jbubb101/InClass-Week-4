# %%
Task_a = (5+(10*4)+20)/6
Task_a
# Out:
# 10.833333333333334

# %%
Task_b = (3+(5*4)+12)/6
Task_b
# Out:
# 5.833333333333333

# %% [markdown]
# <b>😊Alternative Solution😊</b>

# %%
Task_A  = {"O":5,"A":10, "P":20}
Task_B = {"O":3, "A":5, "P":12}


solution_test = (Task_A["O"] + (Task_A["A"]*4) + Task_A["P"]) / 6
print(solution_test)



solution_1 = (Task_B["O"] + Task_B["A"]*4 + Task_B["P"]) / 6
solution_1
# Out:
# 10.833333333333334
# 5.833333333333333

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# Need expected duration.

labels = ['Optimistic','Most Likely', 'Pessimistic']
durations = [Task_A["O"], (Task_A["A"]*4), Task_B["P"]]

plt.bar(labels, durations, color=['green', 'blue', 'red','purple'])
plt.title("PERT Estimation for task Duration")
plt.ylabel("Duration (days)")
plt.show()

fig, ax = plt.subplots()
line, = ax.plot(1,durations, color='blue')

# Line plot for duration
fig, ax = plt.subplots()
x_values = [1, 2, 3]  
line, = ax.plot(x_values, durations, color='blue', marker='o')
ax.set_xticks(x_values)
ax.set_xticklabels(labels)
plt.title("PERT Line Plot for Task A Duration")
plt.ylabel("Duration (days)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 14
#      11 plt.show()
#      13 fig, ax = plt.subplots()
# ---> 14 line, = ax.plot(1,durations, color='blue')
#      16 # Line plot for duration
#      17 fig, ax = plt.subplots()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\axes\_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# ...

# %%
import matplotlib.pyplot as plt

labels = ['Optimistic','Most Likely', 'Pessimistic']
durations = [Task_B["O"], (Task_B["A"]*4), Task_B["P"]]

plt.bar(labels, durations, color=['green', 'blue', 'red','purple'])
plt.title("PERT Estimation for task Duration")
plt.ylabel("Duration (days)")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Example Task durations for PERT
Task_A = {"O": 5, "A": 40, "P": 20, "final": 10.83}  
Task_B = {"O": 6, "A": 32, "P": 12, "final": 5.83}   

# Labels for the bar chart (added 'Final')
labels = ['Optimistic', 'Most Likely', 'Pessimistic', 'Final']

# Durations for the PERT estimate
durations = [Task_A["O"], Task_A["A"], Task_A["P"], Task_A["final"]]

# Bar plot (adjusted colors to match the number of durations)
plt.bar(labels, durations, color=['green', 'blue', 'red', 'purple'])
plt.title("PERT Estimation for Task A Duration")
plt.ylabel("Duration (days)")
plt.show()

# Line plot for duration
fig, ax = plt.subplots()
x_values = [1, 2, 3, 4]  # Corresponding to 'Optimistic', 'Most Likely', 'Pessimistic', 'Final'
line, = ax.plot(x_values, durations, color='blue', marker='o')
ax.set_xticks(x_values)
ax.set_xticklabels(labels)
plt.title("Line Plot for Task A Duration")
plt.ylabel("Duration (days)")
plt.show()

# %%
# Line plot for duration
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Example Task durations for PERT
Task_A = {"O": 5, "A": 40, "P": 20, "final": 10.83}  
Task_B = {"O": 6, "A": 32, "P": 12, "final": 5.83}   

# Labels for the bar chart (added 'Final')
labels = ['Optimistic', 'Most Likely', 'Pessimistic', 'Final']

# Durations for the PERT estimate
durations = [Task_B["O"], Task_B["A"], Task_B["P"], Task_B["final"]]

# Bar plot (adjusted colors to match the number of durations)
plt.bar(labels, durations, color=['green', 'blue', 'red', 'purple'])
plt.title("PERT Estimation for Task A Duration")
plt.ylabel("Duration (days)")
plt.show()

# Line plot for duration
fig, ax = plt.subplots()
x_values = [1, 2, 3, 4]  # Corresponding to 'Optimistic', 'Most Likely', 'Pessimistic', 'Final'
line, = ax.plot(x_values, durations, color='blue', marker='o')
ax.set_xticks(x_values)
ax.set_xticklabels(labels)
plt.title("Line Plot for Task A Duration")
plt.ylabel("Duration (days)")
plt.show()

# %% [markdown]
# 10,000 simulations

# %%
import numpy as np
import matplotlib.pyplot as plt

# Simulation Parameters
n_simulations = 10000




task_1 = {'mean':5,"st_dev":1}
task_2 = {'mean':10,"st_dev":2}
task_3 = {'mean':7,"st_dev":1}

task_1_sim= np.random.normal(task_1['mean'], task_1['st_dev'], n_simulations)
task_2_sim= np.random.normal(task_2['mean'], task_2['st_dev'], n_simulations)
task_3_sim= np.random.normal(task_3['mean'], task_3['st_dev'], n_simulations)

total_time_sim = task_1_sim + task_2_sim + task_3_sim

# Analyze the results
mean_total_time = np.mean(total_time_sim)
st_dev_total_time = np.std(total_time_sim)

print(f"Mean total time: {mean_total_time}")
print(f"Standard deviation of total time: {st_dev_total_time}")
# Out:
# Mean total time: 21.997215751161438
# Standard deviation of total time: 2.46696179029203

# %%
plt.figure(figsize=(12, 6))

plt.hist(task_1_sim, bins=10, color='green', edgecolor='black')
plt.title('Distribution of task 1')
plt.xlabel('Total Revenue (Millions USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))

plt.hist(task_2_sim, bins=10, color='indigo', edgecolor='black')
plt.title('Distribution of task 2')
plt.xlabel('Total Revenue (Millions USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))

plt.hist(task_3_sim, bins=10, color='purple', edgecolor='black')
plt.title('Distribution of task 1')
plt.xlabel('Total Revenue (Millions USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 6))

plt.hist(total_time_sim, bins=10, color='orange', edgecolor='black')
plt.title('Distribution of total task time')
plt.xlabel('Total Revenue (Millions USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

print(f"Mean total time: {mean_total_time}")
print(f"Standard deviation of total time: {st_dev_total_time}")
print(f"Best Case scenario {total_time_sim.max()}")
print(f"Min Case scenario {total_time_sim.max()}")
# Out:
# Mean total time: 21.997215751161438
# Standard deviation of total time: 2.46696179029203
# Best Case scenario 31.663586818654586
# Min Case scenario 31.663586818654586

# %%
print(total_time_sim)
# Out:
# [20.17728148 22.51748908 21.7502298  ... 17.58634104 21.49856352
#  24.14555978]

# %% [markdown]
# PERT & Monte Carlo Simulation

# %%
task_A = {"O":5,"M":10,"P":20}

task_average = (task_A["O"] + (task_A["M"]*4)+ task_A["P"])/6

num_simulations = 10000

total_sim = np.random.normal()


Pert_line = task_average
# Out:
# 10.833333333333334
